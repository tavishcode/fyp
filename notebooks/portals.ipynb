# %%
import pandas as pd
from tqdm.auto import tqdm
import requests
from bs4 import BeautifulSoup
import re

# %%
def find_portal(article):
    try:
        res = requests.get("https://en.wikipedia.org/wiki/" + article)
    except:
        return "None"
    soup = BeautifulSoup(res.text, 'html.parser')
    links=soup.find_all(href=re.compile("Portal"))
    portals = ""
    for l in links:
        try:
            portals += l['title'].split('Portal:')[1] + ";"
        except:
            pass
    if portals:
        portals = portals[:-1]
    return portals

# %%
tqdm.pandas()
df = pd.read_csv('rand_sample.csv', index_col=0)

# %%
df.head()
# Out:
#                                                     Page  2015-07-01  \
# 38573   Main_Page_en.wikipedia.org_all-access_all-agents  20381245.0
# 9774       Main_Page_en.wikipedia.org_desktop_all-agents  11952559.0
# 74114   Main_Page_en.wikipedia.org_mobile-web_all-agents   8039732.0
# 39180  Special:Search_en.wikipedia.org_all-access_all...   2034850.0
# 10403  Special:Search_en.wikipedia.org_desktop_all-ag...   1628266.0
#
#        2015-07-02  2015-07-03  2015-07-04  2015-07-05  2015-07-06  2015-07-07  \
# 38573  20752194.0  19573967.0  20439645.0  20772109.0  22544669.0  21210887.0
# 9774   12344021.0  11195848.0  11982470.0  12379684.0  14164829.0  12917172.0
# 74114   8018607.0   7980511.0   8024814.0   7929962.0   7959839.0   7892357.0
# 39180   1984412.0   1763117.0   1620136.0   1766701.0   2108408.0   2118720.0
# 10403   1576720.0   1375372.0   1226739.0   1336675.0   1699242.0   1709755.0
#
#        2015-07-08  2015-07-09   ...     2016-12-26  2016-12-27  2016-12-28  \
# 38573  19107911.0  19993848.0   ...     28342885.0  26916991.0  27025053.0
# 9774   11089923.0  12067334.0   ...     21473188.0  20065005.0  19751910.0
# 74114   7607871.0   7515302.0   ...      4243273.0   4097335.0   4168668.0
# 39180   2052391.0   2300186.0   ...      1769730.0   1902057.0   1816849.0
# 10403   1653199.0   1892392.0   ...      1358883.0   1481319.0   1399599.0
#
#        2016-12-29  2016-12-30  2016-12-31         total  lang            link  \
# 38573  26073819.0  24363967.0  26149541.0  1.206618e+10    en       Main_Page
# 9774   19211634.0  17100925.0  19591761.0  8.774497e+09    en       Main_Page
# 74114   4100929.0   4118692.0   3939419.0  3.153985e+09    en       Main_Page
# 39180   1895763.0   1811624.0   1576945.0  1.304079e+09    en  Special:Search
# 10403   1455447.0   1397331.0   1175657.0  1.011848e+09    en  Special:Search
#
#        portals
# 38573      NaN
# 9774       NaN
# 74114      NaN
# 39180      NaN
# 10403      NaN
#
# [5 rows x 555 columns]

# %%
df.portals= df['link'].progress_apply(find_portal)
# Out:
# HBox(children=(IntProgress(value=0, max=16384), HTML(value='')))

# %%
df.to_csv('portals.csv')
