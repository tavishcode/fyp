# %%
import pymongo
import pandas as pd 

client = pymongo.MongoClient('mongodb://tavish:1234@cluster0-shard-00-00-anyrv.mongodb.net:27017,'
+'cluster0-shard-00-01-anyrv.mongodb.net:27017,'
+'cluster0-shard-00-02-anyrv.mongodb.net:27017/'
+'test?ssl=true&replicaSet=Cluster0-shard-0&authSource=admin&retryWrites=true')
db = client['test']

runs = db['runs']
metrics= db['metrics']
outfile =  open("result.json","w")

confs = {}
for run in runs.find():
    confs[str(run['_id'])]={'lr': run['config']['lr'],
        'b_size': run['config']['b_size'],
        'w_size': run['config']['w_size'], 
        'dropout': run['config']['dropout']}
    # confs['lr'].append(float(run['config']['lr']))
    # confs['b_size'].append(float(run['config']['b_size']))
    # confs['w_size'].append(float(run['config']['w_size']))
    # confs['dropout'].append(float(run['config']['dropout']))
    # print("RUN RUN ID: " + str(run['_id']))
for metric in metrics.find():
    confs[str(metric['run_id'])]['values'] = metric['values']
    # print("METRIC RUN ID: "+str( metric['run_id']))
    # print("lr" + str(run['config']['lr']) + "b_size: " + str(run['config']['b_size']) + ", w_size: " + str(run['config']['w_size']) + ", dropout: " + str(run['config']['dropout']))
print(confs)

df = pd.DataFrame(confs)
# df=df.sort_values(by=['lr', 'b_size', 'w_size', 'dropout'])
# print(df)
# Out:
# {'1': {'lr': 0.01, 'b_size': 64, 'w_size': 7, 'dropout': 0.2, 'values': [5.635640259832144, 4.311313794925809, 4.652860876172781, 3.7646739883348346, 3.5810858346521854, 3.4595267670229077, 3.4479724606499076, 3.410858342424035, 3.2214261423796415, 3.2971686366945505, 3.1751462910324335, 3.189038034528494, 3.1394133269786835, 3.0735669815912843, 3.1636894522234797, 3.1711571644991636, 3.0231863921508193, 3.0130515405908227, 3.0400339690968394, 3.1328261801972985, 3.0704754553735256, 2.95238973852247, 2.97856299392879, 3.0486011812463403, 3.0482774702832103, 3.055010948330164, 2.9712643306702375, 2.923428206704557, 2.9528213664889336, 2.9087045178748667, 3.0019743740558624, 3.1314825750887394, 15239516.084023925, 4118725.054878071, 7.379749193787575, 7.357207026332617, 7.356343727558851, 7.334198357537389, 7.361899130046368, 7.353733246214688, 7.363292321562767, 7.349272536113858, 7.330712104216218, 7.355135519057512, 7.341162447817624, 7.363114636391401, 7.357270029373467, 7.35042603
# ...

# %%
import matplotlib.pyplot as plt

for exp in confs.values():
    label = "lr: {}, b_size: {}, w_size: {}, dropout: {}".format(exp['lr'],exp['b_size'], exp['w_size'], exp['dropout'])
    ax, fig = plt.subplots()
    print(label)
    fig.plot(exp['values'])
    plt.show()
# Out:
# lr: 0.01, b_size: 64, w_size: 7, dropout: 0.2
# lr: 0.1, b_size: 64, w_size: 7, dropout: 0.2
# lr: 0.1, b_size: 64, w_size: 14, dropout: 0.2
# lr: 0.01, b_size: 64, w_size: 14, dropout: 0.2
# lr: 0.1, b_size: 128, w_size: 7, dropout: 0.2
# lr: 0.1, b_size: 128, w_size: 14, dropout: 0.2
# lr: 0.01, b_size: 128, w_size: 7, dropout: 0.2
# lr: 0.1, b_size: 256, w_size: 7, dropout: 0.2
# lr: 0.01, b_size: 128, w_size: 14, dropout: 0.2
# lr: 0.1, b_size: 256, w_size: 14, dropout: 0.2
# lr: 0.1, b_size: 64, w_size: 7, dropout: 0.4
# lr: 0.01, b_size: 256, w_size: 7, dropout: 0.2
# lr: 0.01, b_size: 256, w_size: 14, dropout: 0.2
# lr: 0.1, b_size: 64, w_size: 14, dropout: 0.4
# lr: 0.01, b_size: 64, w_size: 7, dropout: 0.4
# lr: 0.1, b_size: 128, w_size: 7, dropout: 0.4
# lr: 0.1, b_size: 128, w_size: 14, dropout: 0.4
# lr: 0.01, b_size: 64, w_size: 14, dropout: 0.4
# lr: 0.1, b_size: 256, w_size: 7, dropout: 0.4
# lr: 0.1, b_size: 256, w_size: 14, dropout: 0.4
# ...
